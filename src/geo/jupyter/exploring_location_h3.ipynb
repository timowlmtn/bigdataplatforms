# %%
import h3
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Polygon, box, MultiPolygon, mapping
import json
import geojson

# %%
bbox_ri = box(-71.86277, 41.146339, -71.12057, 42.018798)

# %%
# Convert bounding box to a GeoDataFrame
gdf_bbox_ri = gpd.GeoDataFrame({'geometry': [bbox_ri]}, crs='EPSG:4326')

# %%
def get_h3_hexagons(bounding_box, resolution):
    box_dict = json.loads(geojson.dumps(bounding_box))
    hexagons = h3.polyfill(box_dict, resolution)
    hex_geoms = [Polygon(h3.h3_to_geo_boundary(h, geo_json=True)) for h in hexagons]
    return gpd.GeoDataFrame({'geometry': hex_geoms}, crs='EPSG:4326')

# Generate H3 hexagons for two different resolutions
resolution1 = 8
resolution2 = 9

# %%
ri_hex8 = get_h3_hexagons(geojson.Polygon(geometry=mapping(bbox_ri)), 8)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 ri_hex8 = get_h3_hexagons(geojson.Polygon(geometry=mapping(bbox_ri)), 8)
#
# Cell In[68], line 3, in get_h3_hexagons(bounding_box, resolution)
#       1 def get_h3_hexagons(bounding_box, resolution):
#       2     box_dict = json.loads(geojson.dumps(bounding_box))
# ----> 3     hexagons = h3.polyfill(box_dict, resolution)
#       4     hex_geoms = [Polygon(h3.h3_to_geo_boundary(h, geo_json=True)) for h in hexagons]
#       5     return gpd.GeoDataFrame({'geometry': hex_geoms}, crs='EPSG:4326')
#
# File ~/PycharmProjects/OwlMountain/venv/lib/python3.9/site-packages/h3/api/_api_template.py:530, in _API_FUNCTIONS.polyfill(self, geojson, res, geo_json_conformant)
#     495 def polyfill(self, geojson, res, geo_json_conformant=False):
#     496     """
#     497     Get set of hexagons whose *centers* are contained within
#     498     a GeoJSON-style polygon.
#    (...)
#     528     unordered collection of H3Cell
#     529     """
# --> 530     mv = _cy.polyfill(geojson, res, geo_json_conformant=geo_json_conformant)
#     532     return self._out_unordered(mv)
#
# File geo.pyx:211, in h3._cy.geo.polyfill()
#
# IndexError: list index out of range

# %%
bbox_coords = geojson.Polygon(geometry=mapping(bbox_ri))
bbox_coords
# Out:
# {"coordinates": [], "geometry": {"coordinates": [[[-71.12057, 41.146339], [-71.12057, 42.018798], [-71.86277, 42.018798], [-71.86277, 41.146339], [-71.12057, 41.146339]]], "type": "Polygon"}, "type": "Polygon"}

# %%
bbox_coords
# Out:
# {"coordinates": [], "geometry": {"coordinates": [[[-71.12057, 41.146339], [-71.12057, 42.018798], [-71.86277, 42.018798], [-71.86277, 41.146339], [-71.12057, 41.146339]]], "type": "Polygon"}, "type": "Polygon"}

# %%
polygon = geojson.Polygon([bbox_coords])

# %%
polygon
# Out:
# {"coordinates": [[[-71.12057, 41.146339], [-71.12057, 42.018798], [-71.86277, 42.018798], [-71.86277, 41.146339], [-71.12057, 41.146339]]], "type": "Polygon"}

# %%
ri_hex8 = get_h3_hexagons(polygon, 8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ri_hex8 = get_h3_hexagons(polygon, 8)
#
# Cell In[4], line 2, in get_h3_hexagons(bounding_box, resolution)
#       1 def get_h3_hexagons(bounding_box, resolution):
# ----> 2     hexagons = h3.polyfill(bounding_box.__geo_interface__['coordinates'][0], resolution)
#       3     hex_geoms = [Polygon(h3.h3_to_geo_boundary(h, geo_json=True)) for h in hexagons]
#       4     return gpd.GeoDataFrame({'geometry': hex_geoms}, crs='EPSG:4326')
#
# File ~/PycharmProjects/OwlMountain/venv/lib/python3.9/site-packages/h3/api/_api_template.py:530, in _API_FUNCTIONS.polyfill(self, geojson, res, geo_json_conformant)
#     495 def polyfill(self, geojson, res, geo_json_conformant=False):
#     496     """
#     497     Get set of hexagons whose *centers* are contained within
#     498     a GeoJSON-style polygon.
#    (...)
#     528     unordered collection of H3Cell
#     529     """
# --> 530     mv = _cy.polyfill(geojson, res, geo_json_conformant=geo_json_conformant)
#     532     return self._out_unordered(mv)
#
# TypeError: Argument 'geojson' has incorrect type (expected dict, got list)

# %%
geojson_polygon = {
    "type": "Polygon",
    "coordinates": [[
        [-71.12057, 41.146339],
        [-71.12057, 42.018798],
        [-71.86277, 42.018798],
        [-71.86277, 41.146339],
        [-71.12057, 41.146339]
    ]]
}

# %%
polygon_coords = geojson_polygon['coordinates'][0]

# %%
polygon = Polygon(polygon_coords)
resolution = 8

# %%
polygon.__geo_interface__['coordinates'][0]
# Out:
# ((-71.12057, 41.146339),
#  (-71.12057, 42.018798),
#  (-71.86277, 42.018798),
#  (-71.86277, 41.146339),
#  (-71.12057, 41.146339))

# %%
list(polygon.__geo_interface__['coordinates'][0])
# Out:
# [(-71.12057, 41.146339),
#  (-71.12057, 42.018798),
#  (-71.86277, 42.018798),
#  (-71.86277, 41.146339),
#  (-71.12057, 41.146339)]

# %%
hexagons = h3.polyfill(geojson_polygon, resolution)

# %%
hexagons
# Out:
# {'88e720710bfffff',
#  '88e7200d59fffff',
#  '88e7200c11fffff',
#  '88e7207ab5fffff',
#  '88e7200d23fffff',
#  '88e720029dfffff',
#  '88e7200cb3fffff',
#  '88e72070a7fffff',
#  '88e722b61bfffff',
#  '88e7203319fffff',
#  '88e7207891fffff',
#  '88e7203b11fffff',
#  '88e720700dfffff',
#  '88e72071d5fffff',
#  '88e7200d69fffff',
#  '88e7200d15fffff',
#  '88e7204c43fffff',
#  '88e7204d63fffff',
#  '88e720046bfffff',
#  '88e7200e1bfffff',
#  '88e720310bfffff',
#  '88e7207967fffff',
#  '88e72014abfffff',
#  '88e7200195fffff',
#  '88e7200019fffff',
#  '88e72071e7fffff',
#  '88e720a907fffff',
#  '88e7204d4dfffff',
#  '88e7200dc1fffff',
#  '88e7206333fffff',
#  '88e722b6ddfffff',
#  '88e72072d7fffff',
#  '88e7204d8bfffff',
#  '88e72000d5fffff',
#  '88e7200d13fffff',
#  '88e72078a5fffff',
#  '88e7207609fffff',
#  '88e7204d8dfffff',
#  '88e72004edfffff',
#  '88e7203a01fffff',
#  '88e7204e2bfffff',
#  '88e7207353fffff',
#  '88e7200e63fffff',
#  '88e7200439fffff',
#  '88e7203943fffff',
#  '88e720632dfffff',
#  '88e72046a1fffff',
#  '88e7200e9dfffff',
#  '88e7207647fffff',
#  '88e7204c31fffff',
#  '88e720320bfffff',
#  '88e720158bfffff',
#  '88e7207165fffff',
#  '88e720696bfffff',
#  '88e7206311fffff',
#  '88e7203a15fffff',
#  '88e720090bfffff',
#  '88e7200c0dfffff',
#  '88e72005d5fffff',
#  '88e722b40bfffff',
#  '88e72002d1fffff',
#  '88e7207a27fffff',
#  '88e7200589fffff',
#  '88e7200f0bfffff',
#  '88e7204ca9fffff',
#  '88e720073bfffff',
#  '88e7204553fffff',
#  '88e7206b37fffff',
#  '88e7204e8dfffff',
#  '88e7207607fffff',
#  '88e722b695fffff',
#  '88e720632bfffff',
#  '88e720732bfffff',
#  '88e7207aedfffff',
#  '88e72015a1fffff',
#  '88e7207aa5fffff',
#  '88e7204e8bfffff',
#  '88e7200abdfffff',
#  '88e72016b9fffff',
#  '88e720311dfffff',
#  '88e7204f35fffff',
#  '88e7207b11fffff',
#  '88e720a9d3fffff',
#  '88e7203aedfffff',
#  '88e7204de1fffff',
#  '88e7200495fffff',
#  '88e7200013fffff',
#  '88e7204cd9fffff',
#  '88e720060bfffff',
#  '88e7204dc3fffff',
#  '88e7200ee1fffff',
#  '88e7206a1dfffff',
#  '88e720623bfffff',
#  '88e7200847fffff',
#  '88e72001e5fffff',
#  '88e7200517fffff',
#  '88e7201587fffff',
#  '88e720062bfffff',
#  '88e7203123fffff',
#  '88e7200835fffff',
#  '88e7203927fffff',
#  '88e7200715fffff',
#  '88e720742dfffff',
#  '88e72008b3fffff',
#  '88e72015c5fffff',
#  '88e720705dfffff',
#  '88e7203a25fffff',
#  '88e7203051fffff',
#  '88e7200ac7fffff',
#  '88e72014ddfffff',
#  '88e7204dc7fffff',
#  '88e72009ddfffff',
#  '88e72000ddfffff',
#  ...}

# %%
hex_geoms = [Polygon(h3.h3_to_geo_boundary(h, geo_json=True)) for h in hexagons]

# %%
gdf_hex = gpd.GeoDataFrame({'geometry': hex_geoms}, crs='EPSG:4326')

# %%
# Plot the polygon and H3 hexagons
fig, ax = plt.subplots(figsize=(10, 10))
gdf_hex.boundary.plot(ax=ax, color='black')
gdf_hex.boundary.plot(ax=ax, color='blue', alpha=0.5)
gdf_hex.plot(ax=ax, color='blue', alpha=0.2)
plt.title(f'H3 Hexagons for Resolution {resolution}')
plt.show()

# %%
gdf_bbox
# Out:
#                                             geometry
# 0  POLYGON ((-71.12057 41.14634, -71.12057 42.018...

# %%
hexagons = h3.polyfill(gdf_bbox, resolution)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 hexagons = h3.polyfill(gdf_bbox, resolution)
#
# File ~/PycharmProjects/OwlMountain/venv/lib/python3.9/site-packages/h3/api/_api_template.py:530, in _API_FUNCTIONS.polyfill(self, geojson, res, geo_json_conformant)
#     495 def polyfill(self, geojson, res, geo_json_conformant=False):
#     496     """
#     497     Get set of hexagons whose *centers* are contained within
#     498     a GeoJSON-style polygon.
#    (...)
#     528     unordered collection of H3Cell
#     529     """
# --> 530     mv = _cy.polyfill(geojson, res, geo_json_conformant=geo_json_conformant)
#     532     return self._out_unordered(mv)
#
# TypeError: Argument 'geojson' has incorrect type (expected dict, got GeoDataFrame)

# %%
geojson_polygon = geojson.Feature(geometry=mapping(box_ri))

# %%
geojson_polygon
# Out:
# {"geometry": {"coordinates": [[[-71.12057, 41.146339], [-71.12057, 42.018798], [-71.86277, 42.018798], [-71.86277, 41.146339], [-71.12057, 41.146339]]], "type": "Polygon"}, "properties": {}, "type": "Feature"}

# %%
hexagons = h3.polyfill(geojson_polygon, resolution)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 hexagons = h3.polyfill(geojson_polygon, resolution)
#
# File ~/PycharmProjects/OwlMountain/venv/lib/python3.9/site-packages/h3/api/_api_template.py:530, in _API_FUNCTIONS.polyfill(self, geojson, res, geo_json_conformant)
#     495 def polyfill(self, geojson, res, geo_json_conformant=False):
#     496     """
#     497     Get set of hexagons whose *centers* are contained within
#     498     a GeoJSON-style polygon.
#    (...)
#     528     unordered collection of H3Cell
#     529     """
# --> 530     mv = _cy.polyfill(geojson, res, geo_json_conformant=geo_json_conformant)
#     532     return self._out_unordered(mv)
#
# TypeError: Argument 'geojson' has incorrect type (expected dict, got Feature)

# %%
geojson_polygon = {
    "type": "Polygon",
    "coordinates": [[
        [-71.12057, 41.146339],
        [-71.12057, 42.018798],
        [-71.86277, 42.018798],
        [-71.86277, 41.146339],
        [-71.12057, 41.146339]
    ]]
}

hexagons = h3.polyfill(geojson_polygon, resolution)

# %%
geojson_polygon_convert = geojson.Polygon(geometry=mapping(bbox_ri))
geojson_polygon_convert
geojson_dict = json.loads(geojson.dumps(geojson_polygon))
geojson_dict# geojson_polygon_convert["type"]
# Out:
# {'type': 'Polygon',
#  'coordinates': [[[-71.12057, 41.146339],
#    [-71.12057, 42.018798],
#    [-71.86277, 42.018798],
#    [-71.86277, 41.146339],
#    [-71.12057, 41.146339]]]}

# %%
hexagons = h3.polyfill(geojson_dict, resolution)

# %%
geojson_polygon
# Out:
# {'type': 'Polygon',
#  'coordinates': [[[-71.12057, 41.146339],
#    [-71.12057, 42.018798],
#    [-71.86277, 42.018798],
#    [-71.86277, 41.146339],
#    [-71.12057, 41.146339]]]}

# %%
geojson_dict
# Out:
# {'type': 'Polygon',
#  'coordinates': [[[-71.12057, 41.146339],
#    [-71.12057, 42.018798],
#    [-71.86277, 42.018798],
#    [-71.86277, 41.146339],
#    [-71.12057, 41.146339]]]}

# %%
box_dict = json.loads(geojson.dumps(box_ri))

# %%
h3.geo_to_h3(60.169833, 24.938163, 6)
# Out:
# '861126d37ffffff'

# %%
hexagon_index = h3.geo_to_h3(-71.12057, 42.018798, resolution)
boundary = h3.h3_to_geo_boundary(hexagon_index, geo_json = False)

# %%
h3.h3_to_geo_boundary('861126d37ffffff', geo_json = False)
# Out:
# ((60.15652369744345, 24.85652576115537),
#  (60.134982075460854, 24.895664284494682),
#  (60.1443197767855, 24.948769321085983),
#  (60.175221029708474, 24.9627969933458),
#  (60.19677983831024, 24.923627956201436),
#  (60.18742019244591, 24.870461733016352))

# %%
hexagon_a = h3.geo_to_h3(-71.12057, 42.018798, resolution)
hexagon_b = h3.geo_to_h3(-71.86277, 42.018798, resolution)
kring = h3.h3_distance(hexagon_a, hexagon_b)

# %%
kring
# Out:
# 100
